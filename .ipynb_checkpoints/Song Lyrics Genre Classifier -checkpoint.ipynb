# %%
# importing the necessary packages
import pandas as pd

import spotipy 
from spotipy.oauth2 import SpotifyClientCredentials 
import spotipy.util as util
#Authentication - without user
client_credentials_manager = SpotifyClientCredentials(client_id='304e7b3d10ff42bc8908840c0a2c8b53', \
                                                      client_secret='db384d0b7eb94d11b82e7df56f70801a')
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
import lyricsgenius as lg

# %%
file = open("lyric_test.txt", "w")

# %%
genius = lg.Genius('DLtuEhDwW9p-4iZCZhPLXdNINiL5jnf5dLkFMyt_Is_c5sY0fW4KvyEaxuQyoqwc', \
                   skip_non_songs=True, \
                   excluded_terms=["(Remix)", "(Live)"])

# %%
def get_lyrics(artists, k):
    c = 0
    for name in artists:
        try:
            songs = (genius.search_artist(name, max_songs=k, sort='popularity')).songs
            s = [song.lyrics for song in songs]
            file.write("\n \n   <|endoftext|>   \n \n".join(s))
            c += 1
            print(f"Songs grabbed:{len(s)}")
        except:
            print(f"some exception at {name}: {c}")

# %%
birdy_uri = 'spotify:artist:6FBDaR13swtiWwGhX1WQsP'
results = sp.artist_albums(birdy_uri, album_type='single')
albums = results['items']
while results['next']:
    results = spotify.next(results)
    albums.extend(results['items'])

#for album in albums:
    #print(album['name'])

results_df = pd.DataFrame(data=results['items'])
results_df.head()
# Out:
#   album_group album_type                                            artists  \
# 0      single     single  [{'external_urls': {'spotify': 'https://open.s...
# 1      single     single  [{'external_urls': {'spotify': 'https://open.s...
# 2      single     single  [{'external_urls': {'spotify': 'https://open.s...
# 3      single     single  [{'external_urls': {'spotify': 'https://open.s...
# 4      single     single  [{'external_urls': {'spotify': 'https://open.s...
#
#                                    available_markets  \
# 0  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...
# 1  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...
# 2  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...
# 3  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...
# 4  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/album/3u...
# 1  {'spotify': 'https://open.spotify.com/album/3i...
# ...
